# %% [markdown]
# <a href="https://colab.research.google.com/github/THULASIRAM018/THULASIRAM/blob/main/Python%20preprocesing%20and%20analisys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ca994d6d-79fa-418e-8926-565785489d9d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ca994d6d-79fa-418e-8926-565785489d9d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data = pd.read_csv('companies_data.csv')

# %%
data
# Out:
#         Unnamed: 0                 name  rating  reviews         type  \
# 0                0                  TCS     3.9      NaN       Public
# 1                1            Accenture     4.0      NaN      Private
# 2                2           ICICI Bank     4.1      NaN       Public
# 3                3            Cognizant     3.9      NaN      Private
# 4                4            HDFC Bank     4.0      NaN       Public
# ...            ...                  ...     ...      ...          ...
# 104995       14995        IndusInd Bank     3.6      NaN       Public
# 104996       14996              Samsung     4.2      NaN      Private
# 104997       14997          Indian Army     4.7      NaN  Govt agency
# 104998       14998  Mahindra & Mahindra     4.3      NaN       Public
# 104999       14999             Ericsson     4.1      NaN      Private
#
#                           hq          employee
# 0          Mumbai + 109 more  10000+ employees
# ...

# %%
data.head()
# Out:
#    Unnamed: 0        name  rating  reviews     type                 hq  \
# 0           0         TCS     3.9      NaN   Public  Mumbai + 109 more
# 1           1   Accenture     4.0      NaN  Private   Dublin + 89 more
# 2           2  ICICI Bank     4.1      NaN   Public  Mumbai + 112 more
# 3           3   Cognizant     3.9      NaN  Private  Teaneck + 46 more
# 4           4   HDFC Bank     4.0      NaN   Public  Mumbai + 114 more
#
#            employee
# 0  10000+ employees
# 1  10000+ employees
# 2  10000+ employees
# 3  10000+ employees
# 4  10000+ employees

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105000 entries, 0 to 104999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  105000 non-null  int64
#  1   name        105000 non-null  object
#  2   rating      105000 non-null  float64
#  3   reviews     0 non-null       float64
#  4   type        105000 non-null  object
#  5   hq          105000 non-null  object
#  6   employee    101500 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 5.6+ MB

# %%
data.tail()
# Out:
#         Unnamed: 0                 name  rating  reviews         type  \
# 104995       14995        IndusInd Bank     3.6      NaN       Public
# 104996       14996              Samsung     4.2      NaN      Private
# 104997       14997          Indian Army     4.7      NaN  Govt agency
# 104998       14998  Mahindra & Mahindra     4.3      NaN       Public
# 104999       14999             Ericsson     4.1      NaN      Private
#
#                           hq          employee
# 104995     Mumbai + 113 more  10000+ employees
# 104996      Seoul + 117 more  10000+ employees
# 104997  New Delhi + 114 more  10000+ employees
# 104998     Mumbai + 116 more  10000+ employees
# 104999  Stockholm + 112 more  10000+ employees

# %%
data.shape
# Out:
# (105000, 7)

# %%
data['Unnamed: 0'].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 104995    False
# 104996    False
# 104997    False
# 104998    False
# 104999    False
# Name: Unnamed: 0, Length: 105000, dtype: bool

# %%
data['name'].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 104995    False
# 104996    False
# 104997    False
# 104998    False
# 104999    False
# Name: name, Length: 105000, dtype: bool

# %%
data['rating'].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 104995    False
# 104996    False
# 104997    False
# 104998    False
# 104999    False
# Name: rating, Length: 105000, dtype: bool

# %%
data['reviews'].isna()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 104995    True
# 104996    True
# 104997    True
# 104998    True
# 104999    True
# Name: reviews, Length: 105000, dtype: bool

# %%
data['type'].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 104995    False
# 104996    False
# 104997    False
# 104998    False
# 104999    False
# Name: type, Length: 105000, dtype: bool

# %%
data['hq'].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 104995    False
# 104996    False
# 104997    False
# 104998    False
# 104999    False
# Name: hq, Length: 105000, dtype: bool

# %%
data['employee'].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 104995    False
# 104996    False
# 104997    False
# 104998    False
# 104999    False
# Name: employee, Length: 105000, dtype: bool

# %%
data=data.drop(columns=['reviews'])

# %%
data = data.drop_duplicates()

# %%
data
# Out:
#        Unnamed: 0                 name  rating         type  \
# 0               0                  TCS     3.9       Public
# 1               1            Accenture     4.0      Private
# 2               2           ICICI Bank     4.1       Public
# 3               3            Cognizant     3.9      Private
# 4               4            HDFC Bank     4.0       Public
# ...           ...                  ...     ...          ...
# 29995       29995        IndusInd Bank     3.6       Public
# 29996       29996              Samsung     4.2      Private
# 29997       29997          Indian Army     4.7  Govt agency
# 29998       29998  Mahindra & Mahindra     4.3       Public
# 29999       29999             Ericsson     4.1      Private
#
#                          hq          employee
# 0         Mumbai + 109 more  10000+ employees
# 1          Dublin + 89 more  10000+ employees
# 2         Mumbai + 112 more  10000+ employees
# 3         Teaneck + 46 more  10000+ employees
# ...

# %%
data=data.dropna()

# %%
data
# Out:
#        Unnamed: 0                 name  rating         type  \
# 0               0                  TCS     3.9       Public
# 1               1            Accenture     4.0      Private
# 2               2           ICICI Bank     4.1       Public
# 3               3            Cognizant     3.9      Private
# 4               4            HDFC Bank     4.0       Public
# ...           ...                  ...     ...          ...
# 29995       29995        IndusInd Bank     3.6       Public
# 29996       29996              Samsung     4.2      Private
# 29997       29997          Indian Army     4.7  Govt agency
# 29998       29998  Mahindra & Mahindra     4.3       Public
# 29999       29999             Ericsson     4.1      Private
#
#                          hq          employee
# 0         Mumbai + 109 more  10000+ employees
# 1          Dublin + 89 more  10000+ employees
# 2         Mumbai + 112 more  10000+ employees
# 3         Teaneck + 46 more  10000+ employees
# ...

# %%
data.shape
# Out:
# (29000, 6)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(data['rating'])
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data.corr(numeric_only=True))
plt.show()

# %%
from google.colab import files
data.to_csv('companies_data.csv')
files.download('companies_data.csv')
